# %% [markdown]
# # Detectie van gezichten
#
# ### Stijn Oomes
# donderdag 9 september 2021

# %% [markdown]
# ## Importeer libraries

# %% [markdown]
# Importeer de relevante libraries.
#
# `opencv` en `matplotlib`

# %%
import cv2 as cv

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(cv.__version__)
# Out:
# 4.5.3

# %% [markdown]
# ## Importeer en toon afbeelding

# %% [markdown]
# Zoek een kleuren foto met ongeveer 10 gezichten.
#
# Laad de afbeelding in. Welk datatype heeft de ingeladen afbeelding?
#
# Laat de foto op het scherm zien. Hoeveel gezichten zie je zelf?
#
# Hint: `imread`, `imshow`

# %%
img = plt.imread('groep.jpg')
plt.figure(figsize=(12,10))
plt.imshow(img)
plt.axis('off');

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (300, 400, 3)

# %% [markdown]
# ## Zet een kleurenplaatje om in een grijswaarde plaatje.

# %% [markdown]
# Als je foto al zwart-wit is dan kun je deze stap overslaan.

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %% [markdown]
# ## Initieer detector

# %% [markdown]
# Download de .xml file met de classifier: haarcascade_frontalface_default.xml
#
# Initieer de Cascade Classifier.

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

print("Is de classifier leeg? --> " + str(face_cascade.empty()) + "  (moet 'False', dus 'niet leeg' zijn)")
# Out:
# Is de classifier leeg? --> False  (moet 'False', dus 'niet leeg' zijn)

# %% [markdown]
# ## Detecteer gezichten

# %% [markdown]
# Bepaal met de classifier de gezichten in het plaatje.
#
# Hoeveel heb je er gevonden?

# %%
faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(10, 10),
        flags=cv.CASCADE_SCALE_IMAGE)

print("Aantal gezichten: " + str(faces.shape[0]))
# Out:
# Aantal gezichten: 5

# %% [markdown]
# ## Toon rechthoeken rond gezichten

# %% [markdown]
# Toon rechthoeken om de gevonden gezichten.

# %%
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)

plt.figure(figsize=(15,10))
plt.imshow(img)
plt.axis('off');

# %% [markdown]
# Je kan het ook als zwart-wit plaatje laten zien.

# %%
for (x,y,w,h) in faces:
    cv.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),1)

plt.figure(figsize=(15,10))
plt.imshow(gray, cmap='gray') # colormap aanpassen!
plt.axis('off');

# %% [markdown]
# ## Evalueer de resultaten

# %% [markdown]
# Hoe goed is jouw detector in vergelijking met wat je zelf ziet?
#
# Kun je de parameters van `face_cascade.detectMultiScale` varieren zodat de detectie beter wordt?

# %% [markdown]
# ## Bonus opdracht: detecteer ook de ogen en de mond.

# %% [markdown]
# Een extra uitdaging.
#
# Hint: zijn er nog meer .xml met detectoren?
